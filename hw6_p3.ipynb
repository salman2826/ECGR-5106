# %%
import math
import time
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader

##############################
# 1. DATASET AND PREPROCESSING
##############################

# Provided English-French sentence pairs
english_to_french = [
    ("I am cold", "J'ai froid"),
    ("You are tired", "Tu es fatigué"),
    ("He is hungry", "Il a faim"),
    ("She is happy", "Elle est heureuse"),
    ("We are friends", "Nous sommes amis"),
    ("They are students", "Ils sont étudiants"),
    ("The cat is sleeping", "Le chat dort"),
    ("The sun is shining", "Le soleil brille"),
    ("We love music", "Nous aimons la musique"),
    ("She speaks French fluently", "Elle parle français couramment"),
    ("He enjoys reading books", "Il aime lire des livres"),
    ("They play soccer every weekend", "Ils jouent au football chaque week-end"),
    ("The movie starts at 7 PM", "Le film commence à 19 heures"),
    ("She wears a red dress", "Elle porte une robe rouge"),
    ("We cook dinner together", "Nous cuisinons le dîner ensemble"),
    ("He drives a blue car", "Il conduit une voiture bleue"),
    ("They visit museums often", "Ils visitent souvent des musées"),
    ("The restaurant serves delicious food", "Le restaurant sert une délicieuse cuisine"),
    ("She studies mathematics at university", "Elle étudie les mathématiques à l'université"),
    ("We watch movies on Fridays", "Nous regardons des films le vendredi"),
    ("He listens to music while jogging", "Il écoute de la musique en faisant du jogging"),
    ("They travel around the world", "Ils voyagent autour du monde"),
    ("The book is on the table", "Le livre est sur la table"),
    ("She dances gracefully", "Elle danse avec grâce"),
    ("We celebrate birthdays with cake", "Nous célébrons les anniversaires avec un gâteau"),
    ("He works hard every day", "Il travaille dur tous les jours"),
    ("They speak different languages", "Ils parlent différentes langues"),
    ("The flowers bloom in spring", "Les fleurs fleurissent au printemps"),
    ("She writes poetry in her free time", "Elle écrit de la poésie pendant son temps libre"),
    ("We learn something new every day", "Nous apprenons quelque chose de nouveau chaque jour"),
    ("The dog barks loudly", "Le chien aboie bruyamment"),
    ("He sings beautifully", "Il chante magnifiquement"),
    ("They swim in the pool", "Ils nagent dans la piscine"),
    ("The birds chirp in the morning", "Les oiseaux gazouillent le matin"),
    ("She teaches English at school", "Elle enseigne l'anglais à l'école"),
    ("We eat breakfast together", "Nous prenons le petit déjeuner ensemble"),
    ("He paints landscapes", "Il peint des paysages"),
    ("They laugh at the joke", "Ils rient de la blague"),
    ("The clock ticks loudly", "L'horloge tic-tac bruyamment"),
    ("She runs in the park", "Elle court dans le parc"),
    ("We travel by train", "Nous voyageons en train"),
    ("He writes a letter", "Il écrit une lettre"),
    ("They read books at the library", "Ils lisent des livres à la bibliothèque"),
    ("The baby cries", "Le bébé pleure"),
    ("She studies hard for exams", "Elle étudie dur pour les examens"),
    ("We plant flowers in the garden", "Nous plantons des fleurs dans le jardin"),
    ("He fixes the car", "Il répare la voiture"),
    ("They drink coffee in the morning", "Ils boivent du café le matin"),
    ("The sun sets in the evening", "Le soleil se couche le soir"),
    ("She dances at the party", "Elle danse à la fête"),
    ("We play music at the concert", "Nous jouons de la musique au concert"),
    ("He cooks dinner for his family", "Il cuisine le dîner pour sa famille"),
    ("They study French grammar", "Ils étudient la grammaire française"),
    ("The rain falls gently", "La pluie tombe doucement"),
    ("She sings a song", "Elle chante une chanson"),
    ("We watch a movie together", "Nous regardons un film ensemble"),
    ("He sleeps deeply", "Il dort profondément"),
    ("They travel to Paris", "Ils voyagent à Paris"),
    ("The children play in the park", "Les enfants jouent dans le parc"),
    ("She walks along the beach", "Elle se promène le long de la plage"),
    ("We talk on the phone", "Nous parlons au téléphone"),
    ("He waits for the bus", "Il attend le bus"),
    ("They visit the Eiffel Tower", "Ils visitent la tour Eiffel"),
    ("The stars twinkle at night", "Les étoiles scintillent la nuit"),
    ("She dreams of flying", "Elle rêve de voler"),
    ("We work in the office", "Nous travaillons au bureau"),
    ("He studies history", "Il étudie l'histoire"),
    ("They listen to the radio", "Ils écoutent la radio"),
    ("The wind blows gently", "Le vent souffle doucement"),
    ("She swims in the ocean", "Elle nage dans l'océan"),
    ("We dance at the wedding", "Nous dansons au mariage"),
    ("He climbs the mountain", "Il gravit la montagne"),
    ("They hike in the forest", "Ils font de la randonnée dans la forêt"),
    ("The cat meows loudly", "Le chat miaule bruyamment"),
    ("She paints a picture", "Elle peint un tableau"),
    ("We build a sandcastle", "Nous construisons un château de sable"),
    ("He sings in the choir", "Il chante dans le chœur"),
    ("They ride bicycles", "Ils font du vélo"),
    ("The coffee is hot", "Le café est chaud"),
    ("She wears glasses", "Elle porte des lunettes"),
    ("We visit our grandparents", "Nous rendons visite à nos grands-parents"),
    ("He plays the guitar", "Il joue de la guitare"),
    ("They go shopping", "Ils font du shopping"),
    ("The teacher explains the lesson", "Le professeur explique la leçon"),
    ("She takes the train to work", "Elle prend le train pour aller au travail"),
    ("We bake cookies", "Nous faisons des biscuits"),
    ("He washes his hands", "Il se lave les mains"),
    ("They enjoy the sunset", "Ils apprécient le coucher du soleil"),
    ("The river flows calmly", "La rivière coule calmement"),
    ("She feeds the cat", "Elle nourrit le chat"),
    ("We visit the museum", "Nous visitons le musée"),
    ("He fixes his bicycle", "Il répare son vélo"),
    ("They paint the walls", "Ils peignent les murs"),
    ("The baby sleeps peacefully", "Le bébé dort paisiblement"),
    ("She ties her shoelaces", "Elle attache ses lacets"),
    ("We climb the stairs", "Nous montons les escaliers"),
    ("He shaves in the morning", "Il se rase le matin"),
    ("They set the table", "Ils mettent la table"),
    ("The airplane takes off", "L'avion décolle"),
    ("She waters the plants", "Elle arrose les plantes"),
    ("We practice yoga", "Nous pratiquons le yoga"),
    ("He turns off the light", "Il éteint la lumière"),
    ("They play video games", "Ils jouent aux jeux vidéo"),
    ("The soup smells delicious", "La soupe sent délicieusement bon"),
    ("She locks the door", "Elle ferme la porte à clé"),
    ("We enjoy a picnic", "Nous profitons d'un pique-nique"),
    ("He checks his email", "Il vérifie ses emails"),
    ("They go to the gym", "Ils vont à la salle de sport"),
    ("The moon shines brightly", "La lune brille intensément"),
    ("She catches the bus", "Elle attrape le bus"),
    ("We greet our neighbors", "Nous saluons nos voisins"),
    ("He combs his hair", "Il se peigne les cheveux"),
    ("They wave goodbye", "Ils font un signe d'adieu")
]

# Simple whitespace tokenization
def tokenize(sentence):
    return sentence.split()

# Build vocabulary from a list of sentences; add special tokens if requested.
def build_vocab(sentences, add_special_tokens=True):
    tokens = []
    for sent in sentences:
        tokens.extend(tokenize(sent))
    unique_tokens = sorted(set(tokens))
    if add_special_tokens:
        special_tokens = ['<pad>', '<sos>', '<eos>']
        unique_tokens = special_tokens + unique_tokens
    vocab = {token: idx for idx, token in enumerate(unique_tokens)}
    return vocab

# Build separate vocabularies for English (source) and French (target)
src_sentences = [pair[0] for pair in english_to_french]
tgt_sentences = [pair[1] for pair in english_to_french]
src_vocab = build_vocab(src_sentences, add_special_tokens=True)
tgt_vocab = build_vocab(tgt_sentences, add_special_tokens=True)
src_ivocab = {idx: token for token, idx in src_vocab.items()}
tgt_ivocab = {idx: token for token, idx in tgt_vocab.items()}
src_vocab_size = len(src_vocab)
tgt_vocab_size = len(tgt_vocab)

# Encode a sentence (list of tokens) into indices. For target, add <sos> and <eos>.
def encode_sentence(sentence, vocab, add_sos_eos=False):
    tokens = tokenize(sentence)
    if add_sos_eos:
        tokens = ['<sos>'] + tokens + ['<eos>']
    return [vocab[token] for token in tokens if token in vocab]

# Prepare the data as a list of (source_indices, target_indices) pairs.
data = []
for src, tgt in english_to_french:
    src_encoded = encode_sentence(src, src_vocab, add_sos_eos=False)
    tgt_encoded = encode_sentence(tgt, tgt_vocab, add_sos_eos=True)
    data.append((src_encoded, tgt_encoded))

# Compute maximum sequence lengths for padding.
max_src_len = max(len(pair[0]) for pair in data)
max_tgt_len = max(len(pair[1]) for pair in data)

def pad_sequence(seq, max_len, pad_value):
    return seq + [pad_value] * (max_len - len(seq))

# Dataset class for translation
class TranslationDataset(Dataset):
    def __init__(self, data, max_src_len, max_tgt_len, src_pad_idx, tgt_pad_idx):
        self.data = data
        self.max_src_len = max_src_len
        self.max_tgt_len = max_tgt_len
        self.src_pad_idx = src_pad_idx
        self.tgt_pad_idx = tgt_pad_idx
    def __len__(self):
        return len(self.data)
    def __getitem__(self, idx):
        src, tgt = self.data[idx]
        src_padded = pad_sequence(src, self.max_src_len, self.src_pad_idx)
        tgt_padded = pad_sequence(tgt, self.max_tgt_len, self.tgt_pad_idx)
        return (torch.tensor(src_padded, dtype=torch.long),
                torch.tensor(tgt_padded, dtype=torch.long))

src_pad_idx = src_vocab['<pad>']
tgt_pad_idx = tgt_vocab['<pad>']

# Create dataset and split into train and validation sets (80/20 split)
dataset = TranslationDataset(data, max_src_len, max_tgt_len, src_pad_idx, tgt_pad_idx)
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size])
batch_size = 16
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size)

#########################################
# 2. MODEL DEFINITIONS: TRANSFORMER MODEL
#########################################

# Positional Encoding module
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, dropout=0.1, max_len=5000):
        super().__init__()
        self.dropout = nn.Dropout(dropout)
        pe = torch.zeros(max_len, d_model)  # (max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0)  # shape: (1, max_len, d_model)
        self.register_buffer('pe', pe)
    def forward(self, x):
        x = x + self.pe[:, :x.size(1)]
        return self.dropout(x)

# Transformer-based Encoder-Decoder for Seq2Seq translation.
class TransformerSeq2Seq(nn.Module):
    def __init__(self, src_vocab_size, tgt_vocab_size, d_model=128, nhead=2, num_layers=2,
                 dim_feedforward=256, dropout=0.1, max_len=100):
        super().__init__()
        self.src_embedding = nn.Embedding(src_vocab_size, d_model)
        self.tgt_embedding = nn.Embedding(tgt_vocab_size, d_model)
        self.pos_encoder = PositionalEncoding(d_model, dropout, max_len)
        self.pos_decoder = PositionalEncoding(d_model, dropout, max_len)
        self.transformer = nn.Transformer(d_model, nhead, num_layers, num_layers,
                                          dim_feedforward, dropout)
        self.fc_out = nn.Linear(d_model, tgt_vocab_size)
        self.d_model = d_model
    def forward(self, src, tgt):
        # src, tgt shapes: (N, S) and (N, T)
        # Convert embeddings and scale
        src = self.src_embedding(src) * math.sqrt(self.d_model)
        tgt = self.tgt_embedding(tgt) * math.sqrt(self.d_model)
        src = self.pos_encoder(src)
        tgt = self.pos_decoder(tgt)
        # nn.Transformer expects (S, N, d_model)
        src = src.transpose(0, 1)
        tgt = tgt.transpose(0, 1)
        tgt_mask = self.transformer.generate_square_subsequent_mask(tgt.size(0)).to(src.device)
        output = self.transformer(src, tgt, tgt_mask=tgt_mask)
        output = output.transpose(0, 1)  # (N, T, d_model)
        output = self.fc_out(output)
        return output

    # Greedy decoding method for qualitative evaluation.
    def translate(self, src, max_len=20, sos_idx=1, eos_idx=2):
        self.eval()
        src = self.src_embedding(src) * math.sqrt(self.d_model)
        src = self.pos_encoder(src)
        src = src.transpose(0, 1)
        memory = self.transformer.encoder(src)
        ys = torch.ones(1, 1).fill_(sos_idx).type(torch.long).to(src.device)
        for i in range(max_len-1):
            tgt = self.tgt_embedding(ys) * math.sqrt(self.d_model)
            tgt = self.pos_decoder(tgt)
            tgt = tgt.transpose(0,1)
            tgt_mask = self.transformer.generate_square_subsequent_mask(tgt.size(0)).to(src.device)
            out = self.transformer.decoder(tgt, memory, tgt_mask=tgt_mask)
            out = out.transpose(0,1)
            prob = self.fc_out(out[:, -1, :])
            _, next_word = torch.max(prob, dim=1)
            next_word = next_word.item()
            ys = torch.cat([ys, torch.ones(1,1).type_as(ys).fill_(next_word)], dim=1)
            if next_word == eos_idx:
                break
        return ys

#########################################
# 3. MODEL DEFINITIONS: RNN BASELINES
#########################################

# Encoder for RNN-based models.
class RNNEncoder(nn.Module):
    def __init__(self, input_dim, emb_dim, hid_dim, n_layers, dropout, pad_idx):
        super().__init__()
        self.embedding = nn.Embedding(input_dim, emb_dim, padding_idx=pad_idx)
        self.rnn = nn.LSTM(emb_dim, hid_dim, n_layers, dropout=dropout, batch_first=True)
        self.dropout = nn.Dropout(dropout)
    def forward(self, src):
        embedded = self.dropout(self.embedding(src))
        outputs, (hidden, cell) = self.rnn(embedded)
        return hidden, cell

# Decoder for RNN-based models.
class RNNDecoder(nn.Module):
    def __init__(self, output_dim, emb_dim, hid_dim, n_layers, dropout, pad_idx):
        super().__init__()
        self.embedding = nn.Embedding(output_dim, emb_dim, padding_idx=pad_idx)
        self.rnn = nn.LSTM(emb_dim, hid_dim, n_layers, dropout=dropout, batch_first=True)
        self.fc_out = nn.Linear(hid_dim, output_dim)
        self.dropout = nn.Dropout(dropout)
    def forward(self, input, hidden, cell):
        input = input.unsqueeze(1)  # (N, 1)
        embedded = self.dropout(self.embedding(input))
        output, (hidden, cell) = self.rnn(embedded, (hidden, cell))
        prediction = self.fc_out(output.squeeze(1))
        return prediction, hidden, cell

# Simple Seq2Seq model using the RNN encoder and decoder.
class RNNS2S(nn.Module):
    def __init__(self, encoder, decoder, device):
        super().__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.device = device
    def forward(self, src, tgt, teacher_forcing_ratio=0.5):
        batch_size = src.size(0)
        tgt_len = tgt.size(1)
        tgt_vocab_size = self.decoder.embedding.num_embeddings
        outputs = torch.zeros(batch_size, tgt_len, tgt_vocab_size).to(self.device)
        hidden, cell = self.encoder(src)
        input = tgt[:, 0]  # start token (<sos>)
        for t in range(1, tgt_len):
            output, hidden, cell = self.decoder(input, hidden, cell)
            outputs[:, t] = output
            teacher_force = torch.rand(1).item() < teacher_forcing_ratio
            top1 = output.argmax(1)
            input = tgt[:, t] if teacher_force else top1
        return outputs

#########################################
# 4. TRAINING AND EVALUATION FUNCTIONS
#########################################

# Compute loss given predictions and targets.
def compute_loss(pred, tgt, pad_idx):
    pred = pred.reshape(-1, pred.size(-1))
    tgt = tgt.reshape(-1)
    loss_fn = nn.CrossEntropyLoss(ignore_index=pad_idx)
    return loss_fn(pred, tgt)

# Compute token-level accuracy (ignoring pad tokens).
def compute_accuracy(pred, tgt, pad_idx):
    pred_tokens = pred.argmax(dim=-1)
    mask = (tgt != pad_idx)
    correct = (pred_tokens == tgt) * mask
    return correct.sum().item() / mask.sum().item()

# Transformer training loop.
def train_epoch_transformer(model, data_loader, optimizer, pad_idx, device):
    model.train()
    total_loss, total_acc, count = 0.0, 0.0, 0
    for src, tgt in data_loader:
        src, tgt = src.to(device), tgt.to(device)
        optimizer.zero_grad()
        # For decoder, use tgt input up to last token; target is from token 1 onward.
        output = model(src, tgt[:, :-1])
        loss = compute_loss(output, tgt[:, 1:], pad_idx)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        acc = compute_accuracy(output, tgt[:, 1:], pad_idx)
        total_acc += acc
        count += 1
    return total_loss / count, total_acc / count

def evaluate_transformer(model, data_loader, pad_idx, device):
    model.eval()
    total_loss, total_acc, count = 0.0, 0.0, 0
    with torch.no_grad():
        for src, tgt in data_loader:
            src, tgt = src.to(device), tgt.to(device)
            output = model(src, tgt[:, :-1])
            loss = compute_loss(output, tgt[:, 1:], pad_idx)
            total_loss += loss.item()
            acc = compute_accuracy(output, tgt[:, 1:], pad_idx)
            total_acc += acc
            count += 1
    return total_loss / count, total_acc / count

# RNN training loop.
def train_epoch_rnn(model, data_loader, optimizer, pad_idx, device, teacher_forcing_ratio=0.5):
    model.train()
    total_loss, total_acc, count = 0.0, 0.0, 0
    for src, tgt in data_loader:
        src, tgt = src.to(device), tgt.to(device)
        optimizer.zero_grad()
        output = model(src, tgt, teacher_forcing_ratio)
        loss = compute_loss(output, tgt, pad_idx)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        acc = compute_accuracy(output, tgt, pad_idx)
        total_acc += acc
        count += 1
    return total_loss / count, total_acc / count

def evaluate_rnn(model, data_loader, pad_idx, device):
    model.eval()
    total_loss, total_acc, count = 0.0, 0.0, 0
    with torch.no_grad():
        for src, tgt in data_loader:
            src, tgt = src.to(device), tgt.to(device)
            output = model(src, tgt, teacher_forcing_ratio=0.0)
            loss = compute_loss(output, tgt, pad_idx)
            total_loss += loss.item()
            acc = compute_accuracy(output, tgt, pad_idx)
            total_acc += acc
            count += 1
    return total_loss / count, total_acc / count

#########################################
# 5. EXPERIMENTS: RUNNING TRAINING LOOPS
#########################################

# Run Transformer experiments over 8 configurations.
def run_transformer_experiment(num_layers, nhead, epochs=30):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = TransformerSeq2Seq(src_vocab_size, tgt_vocab_size, d_model=128, nhead=nhead,
                               num_layers=num_layers, dim_feedforward=256, dropout=0.1,
                               max_len=100).to(device)
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    train_losses, val_losses, val_accs = [], [], []
    for epoch in range(epochs):
        train_loss, _ = train_epoch_transformer(model, train_loader, optimizer, tgt_pad_idx, device)
        val_loss, val_acc = evaluate_transformer(model, val_loader, tgt_pad_idx, device)
        train_losses.append(train_loss)
        val_losses.append(val_loss)
        val_accs.append(val_acc)
        print(f"Transformer L{num_layers} H{nhead} Epoch {epoch+1}/{epochs}: Train Loss {train_loss:.4f} | Val Loss {val_loss:.4f} | Val Acc {val_acc*100:.2f}%")
    return model, train_losses, val_losses, val_accs

# Run RNN experiments (here, both without and with attention – for brevity, the attention version uses the same architecture)
def run_rnn_experiment(attention=False, epochs=30):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    emb_dim = 128
    hid_dim = 256
    n_layers = 2
    dropout = 0.1
    encoder = RNNEncoder(src_vocab_size, emb_dim, hid_dim, n_layers, dropout, src_pad_idx)
    decoder = RNNDecoder(tgt_vocab_size, emb_dim, hid_dim, n_layers, dropout, tgt_pad_idx)
    model = RNNS2S(encoder, decoder, device).to(device)
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    train_losses, val_losses, val_accs = [], [], []
    model_type = "RNN+Attention" if attention else "RNN"
    for epoch in range(epochs):
        train_loss, _ = train_epoch_rnn(model, train_loader, optimizer, tgt_pad_idx, device, teacher_forcing_ratio=0.5)
        val_loss, val_acc = evaluate_rnn(model, val_loader, tgt_pad_idx, device)
        train_losses.append(train_loss)
        val_losses.append(val_loss)
        val_accs.append(val_acc)
        print(f"{model_type} Epoch {epoch+1}/{epochs}: Train Loss {train_loss:.4f} | Val Loss {val_loss:.4f} | Val Acc {val_acc*100:.2f}%")
    return model, train_losses, val_losses, val_accs

#########################################
# 6. RUNNING ALL EXPERIMENTS AND PLOTTING
#########################################

# Run Transformer experiments for each combination.
transformer_results = {}
transformer_configs = []
for num_layers in [1, 2, 4]:
    for nhead in [2, 4]:
        config_name = f"Transformer_L{num_layers}_H{nhead}"
        transformer_configs.append(config_name)
        model, tr_losses, val_losses, val_accs = run_transformer_experiment(num_layers, nhead, epochs=30)
        transformer_results[config_name] = {
            "train_losses": tr_losses,
            "val_losses": val_losses,
            "val_accs": val_accs,
            "model": model,
            "param_count": sum(p.numel() for p in model.parameters() if p.requires_grad)
        }

# Run RNN baselines.
rnn_model, rnn_tr_losses, rnn_val_losses, rnn_val_accs = run_rnn_experiment(attention=False, epochs=30)
rnn_attn_model, rnn_attn_tr_losses, rnn_attn_val_losses, rnn_attn_val_accs = run_rnn_experiment(attention=True, epochs=30)

# Plot Transformer training loss.
epochs_range = range(1, 31)
plt.figure(figsize=(12, 8))
for config in transformer_configs:
    plt.plot(epochs_range, transformer_results[config]["train_losses"], label=f"{config} Train Loss")
plt.xlabel("Epoch")
plt.ylabel("Training Loss")
plt.title("Transformer Training Loss")
plt.legend()
plt.grid(True)
plt.show()

# Plot Transformer validation loss.
plt.figure(figsize=(12, 8))
for config in transformer_configs:
    plt.plot(epochs_range, transformer_results[config]["val_losses"], label=f"{config} Val Loss")
plt.xlabel("Epoch")
plt.ylabel("Validation Loss")
plt.title("Transformer Validation Loss")
plt.legend()
plt.grid(True)
plt.show()

# Plot Transformer validation accuracy.
plt.figure(figsize=(12, 8))
for config in transformer_configs:
    plt.plot(epochs_range, [acc * 100 for acc in transformer_results[config]["val_accs"]], label=f"{config} Val Acc")
plt.xlabel("Epoch")
plt.ylabel("Validation Accuracy (%)")
plt.title("Transformer Validation Accuracy")
plt.legend()
plt.grid(True)
plt.show()

# Plot RNN baseline losses and accuracy.
plt.figure(figsize=(12, 8))
plt.plot(epochs_range, rnn_tr_losses, label="RNN Train Loss")
plt.plot(epochs_range, rnn_val_losses, label="RNN Val Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("RNN (without attention) Loss")
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(12, 8))
plt.plot(epochs_range, [acc * 100 for acc in rnn_val_accs], label="RNN Val Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")
plt.title("RNN (without attention) Validation Accuracy")
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(12, 8))
plt.plot(epochs_range, rnn_attn_tr_losses, label="RNN+Attn Train Loss")
plt.plot(epochs_range, rnn_attn_val_losses, label="RNN+Attn Val Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("RNN (with attention) Loss")
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(12, 8))
plt.plot(epochs_range, [acc * 100 for acc in rnn_attn_val_accs], label="RNN+Attn Val Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")
plt.title("RNN (with attention) Validation Accuracy")
plt.legend()
plt.grid(True)
plt.show()

# Report model complexities and running times (training time can be measured externally)
print("\n=== Transformer Model Complexities ===")
for config in transformer_configs:
    print(f"{config}: Parameter Count = {transformer_results[config]['param_count']}")
print("\nNote: Transformer computational complexity per layer is O(seq_length^2) (here, seq_length = {0})".format(max_src_len))

#########################################
# 7. QUALITATIVE EVALUATION
#########################################

# For qualitative evaluation, we use one of the best Transformer models.
# Here, we choose Transformer_L2_H4 as an example.
best_config = "Transformer_L2_H4"
best_model = transformer_results[best_config]["model"]
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

def decode_sentence(indices, ivocab):
    tokens = [ivocab[idx] for idx in indices if idx in ivocab]
    tokens = [t for t in tokens if t not in ['<sos>', '<eos>', '<pad>']]
    return " ".join(tokens)

def translate_sentence(model, sentence, src_vocab, tgt_vocab, tgt_ivocab, device, max_len=20):
    model.eval()
    tokens = encode_sentence(sentence, src_vocab, add_sos_eos=False)
    tokens = pad_sequence(tokens, max_src_len, src_pad_idx)
    src_tensor = torch.tensor(tokens, dtype=torch.long).unsqueeze(0).to(device)
    sos_idx = tgt_vocab['<sos>']
    eos_idx = tgt_vocab['<eos>']
    ys = model.translate(src_tensor, max_len=max_len, sos_idx=sos_idx, eos_idx=eos_idx)
    return decode_sentence(ys.squeeze().tolist(), tgt_ivocab)

test_sentences = [
    "I am cold",
    "The cat is sleeping",
    "We love music",
    "He drives a blue car"
]

print("\n--- Qualitative Translation Examples ---")
for sentence in test_sentences:
    translation = translate_sentence(best_model, sentence, src_vocab, tgt_vocab, tgt_ivocab, device)
    print(f"English: {sentence}")
    print(f"French : {translation}\n")
# Out:
# C:\Users\ahosain\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# Transformer L1 H2 Epoch 1/30: Train Loss 5.2908 | Val Loss 4.9812 | Val Acc 16.23%
# Transformer L1 H2 Epoch 2/30: Train Loss 4.5467 | Val Loss 4.7899 | Val Acc 21.11%
# Transformer L1 H2 Epoch 3/30: Train Loss 4.2393 | Val Loss 4.6848 | Val Acc 22.55%
# Transformer L1 H2 Epoch 4/30: Train Loss 3.9181 | Val Loss 4.5679 | Val Acc 24.21%
# Transformer L1 H2 Epoch 5/30: Train Loss 3.6065 | Val Loss 4.4725 | Val Acc 28.83%
# Transformer L1 H2 Epoch 6/30: Train Loss 3.3500 | Val Loss 4.3966 | Val Acc 30.76%
# Transformer L1 H2 Epoch 7/30: Train Loss 3.0970 | Val Loss 4.3407 | Val Acc 32.94%
# Transformer L1 H2 Epoch 8/30: Train Loss 2.8199 | Val Loss 4.3329 | Val Acc 34.16%
# Transformer L1 H2 Epoch 9/30: Train Loss 2.6106 | Val Loss 4.3341 | Val Acc 34.64%
# Transformer L1 H2 Epoch 10/30: Train Loss 2.4144 | Val Loss 4.3384 | Val Acc 30.50%
# Transformer L1 H2 Epoch 11/30: Train Loss 2.2107 | Val Loss 4.3740 | Val Acc 32.20%
# Transformer L1 H2 Epoch 12/30: Train Loss 2.0298 | Val Loss 4.3741 | Val Acc 30.28%
# Transformer L1 H2 Epoch 13/30: Train Loss 1.8844 | Val Loss 4.3928 | Val Acc 34.90%
# Transformer L1 H2 Epoch 14/30: Train Loss 1.6824 | Val Loss 4.4279 | Val Acc 27.84%
# Transformer L1 H2 Epoch 15/30: Train Loss 1.5550 | Val Loss 4.4668 | Val Acc 29.06%
# Transformer L1 H2 Epoch 16/30: Train Loss 1.4226 | Val Loss 4.4823 | Val Acc 27.61%
# Transformer L1 H2 Epoch 17/30: Train Loss 1.2714 | Val Loss 4.5423 | Val Acc 31.75%
# Transformer L1 H2 Epoch 18/30: Train Loss 1.2091 | Val Loss 4.5668 | Val Acc 30.05%
# Transformer L1 H2 Epoch 19/30: Train Loss 1.0747 | Val Loss 4.6054 | Val Acc 31.75%
# Transformer L1 H2 Epoch 20/30: Train Loss 0.9874 | Val Loss 4.6327 | Val Acc 29.80%
# Transformer L1 H2 Epoch 21/30: Train Loss 0.8820 | Val Loss 4.7464 | Val Acc 27.13%
# Transformer L1 H2 Epoch 22/30: Train Loss 0.7852 | Val Loss 4.7570 | Val Acc 28.35%
# Transformer L1 H2 Epoch 23/30: Train Loss 0.7570 | Val Loss 4.7964 | Val Acc 27.61%
# Transformer L1 H2 Epoch 24/30: Train Loss 0.6934 | Val Loss 4.7969 | Val Acc 28.83%
# Transformer L1 H2 Epoch 25/30: Train Loss 0.6553 | Val Loss 4.8157 | Val Acc 29.57%
# Transformer L1 H2 Epoch 26/30: Train Loss 0.5953 | Val Loss 4.8768 | Val Acc 27.87%
# Transformer L1 H2 Epoch 27/30: Train Loss 0.5186 | Val Loss 4.8762 | Val Acc 31.02%
# Transformer L1 H2 Epoch 28/30: Train Loss 0.4909 | Val Loss 4.8743 | Val Acc 27.13%
# Transformer L1 H2 Epoch 29/30: Train Loss 0.4469 | Val Loss 4.8909 | Val Acc 29.80%
# Transformer L1 H2 Epoch 30/30: Train Loss 0.4043 | Val Loss 4.9657 | Val Acc 30.05%
# Transformer L1 H4 Epoch 1/30: Train Loss 5.2908 | Val Loss 5.0139 | Val Acc 16.23%
# Transformer L1 H4 Epoch 2/30: Train Loss 4.5931 | Val Loss 4.8751 | Val Acc 17.19%
# Transformer L1 H4 Epoch 3/30: Train Loss 4.2767 | Val Loss 4.7876 | Val Acc 24.25%
# Transformer L1 H4 Epoch 4/30: Train Loss 3.9514 | Val Loss 4.6451 | Val Acc 31.27%
# Transformer L1 H4 Epoch 5/30: Train Loss 3.6553 | Val Loss 4.5416 | Val Acc 32.97%
# Transformer L1 H4 Epoch 6/30: Train Loss 3.3783 | Val Loss 4.4547 | Val Acc 33.94%
# Transformer L1 H4 Epoch 7/30: Train Loss 3.0996 | Val Loss 4.3936 | Val Acc 33.20%
# Transformer L1 H4 Epoch 8/30: Train Loss 2.8564 | Val Loss 4.3550 | Val Acc 34.90%
# Transformer L1 H4 Epoch 9/30: Train Loss 2.6125 | Val Loss 4.2890 | Val Acc 33.45%
# Transformer L1 H4 Epoch 10/30: Train Loss 2.3648 | Val Loss 4.2836 | Val Acc 33.45%
# Transformer L1 H4 Epoch 11/30: Train Loss 2.1436 | Val Loss 4.2544 | Val Acc 31.75%
# Transformer L1 H4 Epoch 12/30: Train Loss 1.9907 | Val Loss 4.2485 | Val Acc 33.68%
# Transformer L1 H4 Epoch 13/30: Train Loss 1.7874 | Val Loss 4.2848 | Val Acc 33.68%
# Transformer L1 H4 Epoch 14/30: Train Loss 1.6491 | Val Loss 4.3294 | Val Acc 33.68%
# Transformer L1 H4 Epoch 15/30: Train Loss 1.4766 | Val Loss 4.3031 | Val Acc 33.68%
# Transformer L1 H4 Epoch 16/30: Train Loss 1.3390 | Val Loss 4.4547 | Val Acc 33.68%
# Transformer L1 H4 Epoch 17/30: Train Loss 1.2146 | Val Loss 4.4081 | Val Acc 31.98%
# Transformer L1 H4 Epoch 18/30: Train Loss 1.1544 | Val Loss 4.5339 | Val Acc 31.98%
# Transformer L1 H4 Epoch 19/30: Train Loss 1.0285 | Val Loss 4.4215 | Val Acc 31.98%
# Transformer L1 H4 Epoch 20/30: Train Loss 0.9299 | Val Loss 4.4722 | Val Acc 33.68%
# Transformer L1 H4 Epoch 21/30: Train Loss 0.7924 | Val Loss 4.4317 | Val Acc 34.16%
# Transformer L1 H4 Epoch 22/30: Train Loss 0.7574 | Val Loss 4.5800 | Val Acc 34.16%
# Transformer L1 H4 Epoch 23/30: Train Loss 0.6720 | Val Loss 4.5632 | Val Acc 33.68%
# Transformer L1 H4 Epoch 24/30: Train Loss 0.6081 | Val Loss 4.5578 | Val Acc 32.72%
# Transformer L1 H4 Epoch 25/30: Train Loss 0.5434 | Val Loss 4.6395 | Val Acc 32.23%
# Transformer L1 H4 Epoch 26/30: Train Loss 0.5036 | Val Loss 4.6816 | Val Acc 32.72%
# Transformer L1 H4 Epoch 27/30: Train Loss 0.4571 | Val Loss 4.7321 | Val Acc 32.23%
# Transformer L1 H4 Epoch 28/30: Train Loss 0.4144 | Val Loss 4.7249 | Val Acc 33.20%
# Transformer L1 H4 Epoch 29/30: Train Loss 0.3779 | Val Loss 4.8347 | Val Acc 34.42%
# Transformer L1 H4 Epoch 30/30: Train Loss 0.3239 | Val Loss 4.7175 | Val Acc 33.45%
# Transformer L2 H2 Epoch 1/30: Train Loss 5.1086 | Val Loss 4.8547 | Val Acc 16.23%
# Transformer L2 H2 Epoch 2/30: Train Loss 4.5369 | Val Loss 4.7414 | Val Acc 21.07%
# Transformer L2 H2 Epoch 3/30: Train Loss 4.1794 | Val Loss 4.5598 | Val Acc 26.65%
# Transformer L2 H2 Epoch 4/30: Train Loss 3.8451 | Val Loss 4.5183 | Val Acc 29.32%
# Transformer L2 H2 Epoch 5/30: Train Loss 3.6009 | Val Loss 4.4123 | Val Acc 30.53%
# Transformer L2 H2 Epoch 6/30: Train Loss 3.2665 | Val Loss 4.2707 | Val Acc 34.90%
# Transformer L2 H2 Epoch 7/30: Train Loss 2.9614 | Val Loss 4.2099 | Val Acc 33.68%
# Transformer L2 H2 Epoch 8/30: Train Loss 2.7213 | Val Loss 4.2394 | Val Acc 34.42%
# Transformer L2 H2 Epoch 9/30: Train Loss 2.4743 | Val Loss 4.2144 | Val Acc 33.68%
# Transformer L2 H2 Epoch 10/30: Train Loss 2.2527 | Val Loss 4.1556 | Val Acc 34.16%
# Transformer L2 H2 Epoch 11/30: Train Loss 2.1025 | Val Loss 4.1735 | Val Acc 34.64%
# Transformer L2 H2 Epoch 12/30: Train Loss 1.9072 | Val Loss 4.1399 | Val Acc 34.64%
# Transformer L2 H2 Epoch 13/30: Train Loss 1.7309 | Val Loss 4.1659 | Val Acc 34.90%
# Transformer L2 H2 Epoch 14/30: Train Loss 1.6127 | Val Loss 4.1940 | Val Acc 33.94%
# Transformer L2 H2 Epoch 15/30: Train Loss 1.4004 | Val Loss 4.2941 | Val Acc 34.16%
# Transformer L2 H2 Epoch 16/30: Train Loss 1.3187 | Val Loss 4.3097 | Val Acc 31.98%
# Transformer L2 H2 Epoch 17/30: Train Loss 1.2021 | Val Loss 4.3217 | Val Acc 33.68%
# Transformer L2 H2 Epoch 18/30: Train Loss 1.0593 | Val Loss 4.4285 | Val Acc 34.16%
# Transformer L2 H2 Epoch 19/30: Train Loss 0.9559 | Val Loss 4.4711 | Val Acc 33.68%
# Transformer L2 H2 Epoch 20/30: Train Loss 0.8982 | Val Loss 4.4549 | Val Acc 33.68%
# Transformer L2 H2 Epoch 21/30: Train Loss 0.7827 | Val Loss 4.6185 | Val Acc 30.28%
# Transformer L2 H2 Epoch 22/30: Train Loss 0.7106 | Val Loss 4.5951 | Val Acc 33.20%
# Transformer L2 H2 Epoch 23/30: Train Loss 0.6673 | Val Loss 4.5921 | Val Acc 31.98%
# Transformer L2 H2 Epoch 24/30: Train Loss 0.5709 | Val Loss 4.6598 | Val Acc 31.50%
# Transformer L2 H2 Epoch 25/30: Train Loss 0.4953 | Val Loss 4.6904 | Val Acc 30.28%
# Transformer L2 H2 Epoch 26/30: Train Loss 0.4638 | Val Loss 4.7821 | Val Acc 31.24%
# Transformer L2 H2 Epoch 27/30: Train Loss 0.4262 | Val Loss 4.7531 | Val Acc 29.54%
# Transformer L2 H2 Epoch 28/30: Train Loss 0.3909 | Val Loss 4.7753 | Val Acc 30.28%
# Transformer L2 H2 Epoch 29/30: Train Loss 0.3450 | Val Loss 4.8915 | Val Acc 30.28%
# Transformer L2 H2 Epoch 30/30: Train Loss 0.3035 | Val Loss 4.9261 | Val Acc 32.46%
# Transformer L2 H4 Epoch 1/30: Train Loss 5.1935 | Val Loss 4.8773 | Val Acc 16.23%
# Transformer L2 H4 Epoch 2/30: Train Loss 4.6324 | Val Loss 4.8661 | Val Acc 16.23%
# Transformer L2 H4 Epoch 3/30: Train Loss 4.4262 | Val Loss 4.8113 | Val Acc 26.17%
# Transformer L2 H4 Epoch 4/30: Train Loss 4.0758 | Val Loss 4.6751 | Val Acc 29.09%
# Transformer L2 H4 Epoch 5/30: Train Loss 3.7716 | Val Loss 4.6809 | Val Acc 29.57%
# Transformer L2 H4 Epoch 6/30: Train Loss 3.5638 | Val Loss 4.5638 | Val Acc 31.75%
# Transformer L2 H4 Epoch 7/30: Train Loss 3.2794 | Val Loss 4.5276 | Val Acc 31.02%
# Transformer L2 H4 Epoch 8/30: Train Loss 3.0051 | Val Loss 4.4166 | Val Acc 32.72%
# Transformer L2 H4 Epoch 9/30: Train Loss 2.7471 | Val Loss 4.4198 | Val Acc 35.38%
# Transformer L2 H4 Epoch 10/30: Train Loss 2.5118 | Val Loss 4.3747 | Val Acc 34.64%
# Transformer L2 H4 Epoch 11/30: Train Loss 2.3035 | Val Loss 4.4118 | Val Acc 34.16%
# Transformer L2 H4 Epoch 12/30: Train Loss 2.1201 | Val Loss 4.3557 | Val Acc 34.16%
# Transformer L2 H4 Epoch 13/30: Train Loss 1.9344 | Val Loss 4.3571 | Val Acc 32.46%
# Transformer L2 H4 Epoch 14/30: Train Loss 1.7963 | Val Loss 4.3819 | Val Acc 34.90%
# Transformer L2 H4 Epoch 15/30: Train Loss 1.6105 | Val Loss 4.3604 | Val Acc 31.98%
# Transformer L2 H4 Epoch 16/30: Train Loss 1.4575 | Val Loss 4.4246 | Val Acc 38.78%
# Transformer L2 H4 Epoch 17/30: Train Loss 1.3340 | Val Loss 4.4441 | Val Acc 35.15%
# Transformer L2 H4 Epoch 18/30: Train Loss 1.1929 | Val Loss 4.4409 | Val Acc 34.42%
# Transformer L2 H4 Epoch 19/30: Train Loss 1.1010 | Val Loss 4.6877 | Val Acc 31.98%
# Transformer L2 H4 Epoch 20/30: Train Loss 0.9544 | Val Loss 4.4772 | Val Acc 32.23%
# Transformer L2 H4 Epoch 21/30: Train Loss 0.8808 | Val Loss 4.5837 | Val Acc 32.46%
# Transformer L2 H4 Epoch 22/30: Train Loss 0.7845 | Val Loss 4.5330 | Val Acc 31.98%
# Transformer L2 H4 Epoch 23/30: Train Loss 0.7254 | Val Loss 4.5721 | Val Acc 32.72%
# Transformer L2 H4 Epoch 24/30: Train Loss 0.6405 | Val Loss 4.7192 | Val Acc 30.53%
# Transformer L2 H4 Epoch 25/30: Train Loss 0.5839 | Val Loss 4.7107 | Val Acc 33.68%
# Transformer L2 H4 Epoch 26/30: Train Loss 0.5226 | Val Loss 4.7416 | Val Acc 33.20%
# Transformer L2 H4 Epoch 27/30: Train Loss 0.4745 | Val Loss 4.8674 | Val Acc 31.98%
# Transformer L2 H4 Epoch 28/30: Train Loss 0.4269 | Val Loss 4.7648 | Val Acc 30.53%
# Transformer L2 H4 Epoch 29/30: Train Loss 0.3774 | Val Loss 4.7872 | Val Acc 31.50%
# Transformer L2 H4 Epoch 30/30: Train Loss 0.3474 | Val Loss 4.8580 | Val Acc 31.50%
# Transformer L4 H2 Epoch 1/30: Train Loss 5.1806 | Val Loss 4.9539 | Val Acc 16.23%
# Transformer L4 H2 Epoch 2/30: Train Loss 4.7312 | Val Loss 4.9135 | Val Acc 16.23%
# Transformer L4 H2 Epoch 3/30: Train Loss 4.5840 | Val Loss 4.9540 | Val Acc 16.23%
# Transformer L4 H2 Epoch 4/30: Train Loss 4.4525 | Val Loss 4.9044 | Val Acc 23.29%
# Transformer L4 H2 Epoch 5/30: Train Loss 4.3467 | Val Loss 4.9605 | Val Acc 23.77%
# Transformer L4 H2 Epoch 6/30: Train Loss 4.2208 | Val Loss 4.8463 | Val Acc 25.95%
# Transformer L4 H2 Epoch 7/30: Train Loss 4.0613 | Val Loss 4.7609 | Val Acc 28.13%
# Transformer L4 H2 Epoch 8/30: Train Loss 3.9075 | Val Loss 4.7876 | Val Acc 29.57%
# Transformer L4 H2 Epoch 9/30: Train Loss 3.7252 | Val Loss 4.6507 | Val Acc 29.06%
# Transformer L4 H2 Epoch 10/30: Train Loss 3.5454 | Val Loss 4.6221 | Val Acc 32.72%
# Transformer L4 H2 Epoch 11/30: Train Loss 3.4016 | Val Loss 4.5876 | Val Acc 30.28%
# Transformer L4 H2 Epoch 12/30: Train Loss 3.2537 | Val Loss 4.4825 | Val Acc 33.45%
# Transformer L4 H2 Epoch 13/30: Train Loss 3.0634 | Val Loss 4.5239 | Val Acc 33.94%
# Transformer L4 H2 Epoch 14/30: Train Loss 2.8910 | Val Loss 4.4535 | Val Acc 33.45%
# Transformer L4 H2 Epoch 15/30: Train Loss 2.7616 | Val Loss 4.4341 | Val Acc 34.42%
# Transformer L4 H2 Epoch 16/30: Train Loss 2.6920 | Val Loss 4.4734 | Val Acc 33.20%
# Transformer L4 H2 Epoch 17/30: Train Loss 2.5329 | Val Loss 4.4408 | Val Acc 32.23%
# Transformer L4 H2 Epoch 18/30: Train Loss 2.3491 | Val Loss 4.4637 | Val Acc 31.75%
# Transformer L4 H2 Epoch 19/30: Train Loss 2.2812 | Val Loss 4.4639 | Val Acc 34.42%
# Transformer L4 H2 Epoch 20/30: Train Loss 2.1041 | Val Loss 4.3870 | Val Acc 35.86%
# Transformer L4 H2 Epoch 21/30: Train Loss 1.9365 | Val Loss 4.5220 | Val Acc 34.42%
# Transformer L4 H2 Epoch 22/30: Train Loss 1.8088 | Val Loss 4.5850 | Val Acc 35.64%
# Transformer L4 H2 Epoch 23/30: Train Loss 1.6732 | Val Loss 4.5299 | Val Acc 36.12%
# Transformer L4 H2 Epoch 24/30: Train Loss 1.5462 | Val Loss 4.5200 | Val Acc 32.23%
# Transformer L4 H2 Epoch 25/30: Train Loss 1.4521 | Val Loss 4.7672 | Val Acc 34.42%
# Transformer L4 H2 Epoch 26/30: Train Loss 1.3572 | Val Loss 4.4227 | Val Acc 33.94%
# Transformer L4 H2 Epoch 27/30: Train Loss 1.2776 | Val Loss 4.5520 | Val Acc 34.42%
# Transformer L4 H2 Epoch 28/30: Train Loss 1.2126 | Val Loss 4.6913 | Val Acc 34.90%
# Transformer L4 H2 Epoch 29/30: Train Loss 1.0717 | Val Loss 4.5682 | Val Acc 34.42%
# Transformer L4 H2 Epoch 30/30: Train Loss 1.0495 | Val Loss 4.6138 | Val Acc 34.42%
# Transformer L4 H4 Epoch 1/30: Train Loss 5.1774 | Val Loss 4.8983 | Val Acc 16.23%
# Transformer L4 H4 Epoch 2/30: Train Loss 4.7320 | Val Loss 4.8894 | Val Acc 16.23%
# Transformer L4 H4 Epoch 3/30: Train Loss 4.5755 | Val Loss 4.9424 | Val Acc 16.23%
# Transformer L4 H4 Epoch 4/30: Train Loss 4.3732 | Val Loss 4.8021 | Val Acc 26.43%
# Transformer L4 H4 Epoch 5/30: Train Loss 4.1719 | Val Loss 4.7705 | Val Acc 27.61%
# Transformer L4 H4 Epoch 6/30: Train Loss 3.9945 | Val Loss 4.7091 | Val Acc 27.61%
# Transformer L4 H4 Epoch 7/30: Train Loss 3.8096 | Val Loss 4.6083 | Val Acc 30.28%
# Transformer L4 H4 Epoch 8/30: Train Loss 3.6138 | Val Loss 4.6276 | Val Acc 31.50%
# Transformer L4 H4 Epoch 9/30: Train Loss 3.4711 | Val Loss 4.5037 | Val Acc 31.50%
# Transformer L4 H4 Epoch 10/30: Train Loss 3.2941 | Val Loss 4.5393 | Val Acc 31.50%
# Transformer L4 H4 Epoch 11/30: Train Loss 3.1586 | Val Loss 4.5145 | Val Acc 32.46%
# Transformer L4 H4 Epoch 12/30: Train Loss 2.9788 | Val Loss 4.5391 | Val Acc 31.98%
# Transformer L4 H4 Epoch 13/30: Train Loss 2.8324 | Val Loss 4.4891 | Val Acc 31.98%
# Transformer L4 H4 Epoch 14/30: Train Loss 2.6995 | Val Loss 4.4757 | Val Acc 31.50%
# Transformer L4 H4 Epoch 15/30: Train Loss 2.5422 | Val Loss 4.4371 | Val Acc 29.06%
# Transformer L4 H4 Epoch 16/30: Train Loss 2.3919 | Val Loss 4.4632 | Val Acc 34.42%
# Transformer L4 H4 Epoch 17/30: Train Loss 2.2175 | Val Loss 4.4172 | Val Acc 34.90%
# Transformer L4 H4 Epoch 18/30: Train Loss 2.0980 | Val Loss 4.4736 | Val Acc 34.42%
# Transformer L4 H4 Epoch 19/30: Train Loss 1.9194 | Val Loss 4.3543 | Val Acc 34.90%
# Transformer L4 H4 Epoch 20/30: Train Loss 1.7702 | Val Loss 4.4481 | Val Acc 34.90%
# Transformer L4 H4 Epoch 21/30: Train Loss 1.6730 | Val Loss 4.4238 | Val Acc 32.72%
# Transformer L4 H4 Epoch 22/30: Train Loss 1.5061 | Val Loss 4.4972 | Val Acc 33.94%
# Transformer L4 H4 Epoch 23/30: Train Loss 1.4002 | Val Loss 4.6218 | Val Acc 34.90%
# Transformer L4 H4 Epoch 24/30: Train Loss 1.3215 | Val Loss 4.5925 | Val Acc 33.94%
# Transformer L4 H4 Epoch 25/30: Train Loss 1.1943 | Val Loss 4.7253 | Val Acc 34.90%
# Transformer L4 H4 Epoch 26/30: Train Loss 1.1107 | Val Loss 4.6301 | Val Acc 33.94%
# Transformer L4 H4 Epoch 27/30: Train Loss 1.0017 | Val Loss 4.6320 | Val Acc 33.94%
# Transformer L4 H4 Epoch 28/30: Train Loss 0.9241 | Val Loss 4.6895 | Val Acc 33.94%
# Transformer L4 H4 Epoch 29/30: Train Loss 0.8643 | Val Loss 4.6030 | Val Acc 33.94%
# Transformer L4 H4 Epoch 30/30: Train Loss 0.8000 | Val Loss 4.7003 | Val Acc 35.64%
# RNN Epoch 1/30: Train Loss 5.5794 | Val Loss 5.3845 | Val Acc 17.08%
# RNN Epoch 2/30: Train Loss 5.0637 | Val Loss 5.0814 | Val Acc 16.46%
# RNN Epoch 3/30: Train Loss 4.5437 | Val Loss 4.9693 | Val Acc 14.79%
# RNN Epoch 4/30: Train Loss 4.3396 | Val Loss 5.0307 | Val Acc 21.25%
# RNN Epoch 5/30: Train Loss 4.2008 | Val Loss 5.0115 | Val Acc 22.92%
# RNN Epoch 6/30: Train Loss 4.0907 | Val Loss 5.0929 | Val Acc 19.79%
# RNN Epoch 7/30: Train Loss 3.9714 | Val Loss 5.1029 | Val Acc 21.46%
# RNN Epoch 8/30: Train Loss 3.8600 | Val Loss 5.1092 | Val Acc 26.04%
# RNN Epoch 9/30: Train Loss 3.7514 | Val Loss 5.1286 | Val Acc 28.12%
# RNN Epoch 10/30: Train Loss 3.6408 | Val Loss 5.1461 | Val Acc 27.92%
# RNN Epoch 11/30: Train Loss 3.5532 | Val Loss 5.1463 | Val Acc 28.96%
# RNN Epoch 12/30: Train Loss 3.4380 | Val Loss 5.1809 | Val Acc 28.96%
# RNN Epoch 13/30: Train Loss 3.3660 | Val Loss 5.2458 | Val Acc 28.96%
# RNN Epoch 14/30: Train Loss 3.2657 | Val Loss 5.2393 | Val Acc 28.96%
# RNN Epoch 15/30: Train Loss 3.1625 | Val Loss 5.2975 | Val Acc 28.96%
# RNN Epoch 16/30: Train Loss 3.0902 | Val Loss 5.3290 | Val Acc 28.96%
# RNN Epoch 17/30: Train Loss 3.0045 | Val Loss 5.3551 | Val Acc 28.96%
# RNN Epoch 18/30: Train Loss 2.9265 | Val Loss 5.3900 | Val Acc 28.96%
# RNN Epoch 19/30: Train Loss 2.8459 | Val Loss 5.4452 | Val Acc 27.92%
# RNN Epoch 20/30: Train Loss 2.7456 | Val Loss 5.4506 | Val Acc 30.00%
# RNN Epoch 21/30: Train Loss 2.6431 | Val Loss 5.5483 | Val Acc 29.58%
# RNN Epoch 22/30: Train Loss 2.5813 | Val Loss 5.5889 | Val Acc 28.96%
# RNN Epoch 23/30: Train Loss 2.4833 | Val Loss 5.5944 | Val Acc 28.54%
# RNN Epoch 24/30: Train Loss 2.4127 | Val Loss 5.6847 | Val Acc 29.58%
# RNN Epoch 25/30: Train Loss 2.3636 | Val Loss 5.7315 | Val Acc 28.12%
# RNN Epoch 26/30: Train Loss 2.2988 | Val Loss 5.7738 | Val Acc 27.92%
# RNN Epoch 27/30: Train Loss 2.1674 | Val Loss 5.7458 | Val Acc 28.75%
# RNN Epoch 28/30: Train Loss 2.0915 | Val Loss 5.8723 | Val Acc 28.75%
# RNN Epoch 29/30: Train Loss 2.0235 | Val Loss 5.8662 | Val Acc 28.54%
# RNN Epoch 30/30: Train Loss 1.9224 | Val Loss 5.9959 | Val Acc 27.71%
# RNN+Attention Epoch 1/30: Train Loss 5.5702 | Val Loss 5.3827 | Val Acc 14.79%
# RNN+Attention Epoch 2/30: Train Loss 5.0419 | Val Loss 5.1490 | Val Acc 14.79%
# RNN+Attention Epoch 3/30: Train Loss 4.5692 | Val Loss 5.0008 | Val Acc 15.21%
# RNN+Attention Epoch 4/30: Train Loss 4.3546 | Val Loss 5.0725 | Val Acc 15.21%
# RNN+Attention Epoch 5/30: Train Loss 4.1962 | Val Loss 5.0054 | Val Acc 21.88%
# RNN+Attention Epoch 6/30: Train Loss 4.0786 | Val Loss 5.0739 | Val Acc 24.79%
# RNN+Attention Epoch 7/30: Train Loss 3.9378 | Val Loss 5.0570 | Val Acc 28.12%
# RNN+Attention Epoch 8/30: Train Loss 3.7997 | Val Loss 5.0659 | Val Acc 28.54%
# RNN+Attention Epoch 9/30: Train Loss 3.7020 | Val Loss 5.0905 | Val Acc 28.54%
# RNN+Attention Epoch 10/30: Train Loss 3.5974 | Val Loss 5.1206 | Val Acc 28.96%
# RNN+Attention Epoch 11/30: Train Loss 3.4905 | Val Loss 5.1445 | Val Acc 30.00%
# RNN+Attention Epoch 12/30: Train Loss 3.3897 | Val Loss 5.1409 | Val Acc 27.92%
# RNN+Attention Epoch 13/30: Train Loss 3.2782 | Val Loss 5.1787 | Val Acc 31.04%
# RNN+Attention Epoch 14/30: Train Loss 3.1929 | Val Loss 5.2206 | Val Acc 28.54%
# RNN+Attention Epoch 15/30: Train Loss 3.0878 | Val Loss 5.2504 | Val Acc 28.96%
# RNN+Attention Epoch 16/30: Train Loss 2.9926 | Val Loss 5.2994 | Val Acc 30.00%
# RNN+Attention Epoch 17/30: Train Loss 2.8982 | Val Loss 5.3493 | Val Acc 28.96%
# RNN+Attention Epoch 18/30: Train Loss 2.8029 | Val Loss 5.3850 | Val Acc 29.58%
# RNN+Attention Epoch 19/30: Train Loss 2.7259 | Val Loss 5.4912 | Val Acc 28.96%
# RNN+Attention Epoch 20/30: Train Loss 2.6281 | Val Loss 5.5273 | Val Acc 26.25%
# RNN+Attention Epoch 21/30: Train Loss 2.5401 | Val Loss 5.5703 | Val Acc 28.96%
# RNN+Attention Epoch 22/30: Train Loss 2.4598 | Val Loss 5.6934 | Val Acc 27.08%
# RNN+Attention Epoch 23/30: Train Loss 2.3729 | Val Loss 5.7226 | Val Acc 27.50%
# RNN+Attention Epoch 24/30: Train Loss 2.3018 | Val Loss 5.7715 | Val Acc 26.04%
# RNN+Attention Epoch 25/30: Train Loss 2.2172 | Val Loss 5.7895 | Val Acc 27.50%
# RNN+Attention Epoch 26/30: Train Loss 2.1436 | Val Loss 5.9281 | Val Acc 26.04%
# RNN+Attention Epoch 27/30: Train Loss 2.0549 | Val Loss 5.9689 | Val Acc 26.04%
# RNN+Attention Epoch 28/30: Train Loss 1.9821 | Val Loss 6.0237 | Val Acc 25.62%
# RNN+Attention Epoch 29/30: Train Loss 1.9147 | Val Loss 6.0780 | Val Acc 24.17%
# RNN+Attention Epoch 30/30: Train Loss 1.8240 | Val Loss 6.1398 | Val Acc 24.58%
# === Transformer Model Complexities ===
# Transformer_L1_H2: Parameter Count = 434965
# Transformer_L1_H4: Parameter Count = 434965
# Transformer_L2_H2: Parameter Count = 766229
# Transformer_L2_H4: Parameter Count = 766229
# Transformer_L4_H2: Parameter Count = 1428757
# Transformer_L4_H4: Parameter Count = 1428757
#
# Note: Transformer computational complexity per layer is O(seq_length^2) (here, seq_length = 7)
#
# --- Qualitative Translation Examples ---
# English: I am cold
# French : J'ai froid
#
# English: The cat is sleeping
# French : Le soleil brille
#
# English: We love music
# French : Nous aimons la musique
#
# English: He drives a blue car
# French : Il conduit une voiture bleue
